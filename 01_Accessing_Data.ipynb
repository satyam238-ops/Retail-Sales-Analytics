# %%
import pandas as pd
from datasets import load_dataset

dataset = load_dataset("tundesta18/sales-forecast-dataset")
df=dataset['train'].to_pandas()
df.columns=df.columns.str.lower()
# Out:
# Repo card metadata block was not found. Setting CardData to empty.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
df.head()
# Out:
#   product_id product_sugar_content        product_type store_id store_size  \
# 0     FD6114             Low Sugar        Frozen Foods   OUT004     Medium
# 1     FD5075               Regular              Canned   OUT001       High
# 2     FD8233             Low Sugar        Baking Goods   OUT001       High
# 3     NC1180              No Sugar  Health and Hygiene   OUT002      Small
# 4     FD5680             Low Sugar         Snack Foods   OUT004     Medium
#
#   store_location_city_type         store_type  product_weight  \
# 0                   Tier 2  Supermarket Type2           12.66
# 1                   Tier 2  Supermarket Type1           14.28
# 2                   Tier 2  Supermarket Type1           12.10
# 3                   Tier 3          Food Mart            9.57
# 4                   Tier 2  Supermarket Type2           12.03
#
#    product_allocated_area  product_mrp  store_establishment_year  \
# 0                   0.027       117.08                    2009.0
# 1                   0.031       162.08                    1987.0
# 2                   0.112       186.31                    1987.0
# 3                   0.010       123.67                    1998.0
# 4                   0.053       113.64                    2009.0
#
#    product_store_sales_total
# 0                    2842.40
# 1                    4130.16
# 2                    4132.18
# 3                    2279.36
# 4                    2629.15

# %%
df.isnull().sum()
# Out:
# product_id                   0
# product_sugar_content        0
# product_type                 0
# store_id                     0
# store_size                   0
# store_location_city_type     0
# store_type                   0
# product_weight               0
# product_allocated_area       0
# product_mrp                  0
# store_establishment_year     0
# product_store_sales_total    0
# dtype: int64

# %%
print(df.size)
print(df.shape)
print(df.duplicated().sum())
# Out:
# 88968
# (7414, 12)
# 0

# %%
df.to_csv("retail_sales.csv", index=False)
